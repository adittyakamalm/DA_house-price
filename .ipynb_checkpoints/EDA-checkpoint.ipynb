# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
house = pd.read_csv('Antapani.csv')

# %%
house.head()
# Out:
#                                                 Link  \
# 0  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 2  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 3  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 4  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                Judul Kecamatan  Lahan Parkir  \
# 0     Rumah Murah Jalan Sunda Asia Afrika Jarang Ada  Antapani           6.0
# 1            Rumah Minimalis Siap Huni di pusat kota  Antapani           2.0
# 2         JUAL MURAH RUMAH LOKASI PREMIUM DI BANDUNG  Antapani           NaN
# 3  Rumah Industri di Turangga Buahbatu dkt Sailen...  Antapani           2.0
# 4    Rumah ready baru industrial diturangga buahbatu  Antapani           2.0
#
#    Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah             Harga
# 0          3.0          4.0          500.0       568.0  Rp11.000.000.000
# 1          5.0          3.0          370.0       259.0  Rp18.000.000.000
# 2          8.0          6.0          693.0      1035.0  Rp27.000.000.000
# 3          4.0          3.0          131.0       108.0   Rp2.500.000.100
# 4          4.0          3.0          131.0       108.0   Rp2.500.000.000

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Link           1080 non-null   object
#  1   Judul          1080 non-null   object
#  2   Kecamatan      1080 non-null   object
#  3   Lahan Parkir   564 non-null    float64
#  4   Kamar Tidur    1077 non-null   float64
#  5   Kamar Mandi    1077 non-null   float64
#  6   Luas Bangunan  1077 non-null   float64
#  7   Luas Tanah     1077 non-null   float64
#  8   Harga          1080 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 76.1+ KB

# %%
duplicate = house[house.duplicated(['Judul', 'Lahan Parkir', 'Kamar Tidur', 'Kamar Mandi', 'Luas Tanah', 'Luas Bangunan', 'Harga'])]
duplicate
# Out:
#                                                    Link  \
# 13    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 77    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 78    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 80    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 90    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 129   https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 214   https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 416   https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 911   https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1028  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1029  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                   Judul Kecamatan  \
# 13    DIJUAL KOST AKTIF 2 LANTAI AKSES GANG DI AHMAD...  Antapani
# 77    Termurah Rumah Jarang Ada Di Antapani Bandung ...  Antapani
# 78    Termurah Rumah Jarang Ada Di Antapani Bandung ...  Antapani
# 80    DIJUAL RUMAH TINGGAL SIAP HUNI DI ANTAPANI KOT...  Antapani
# 90                              rumah murah di antapani  Antapani
# 129   DIJUAL RUMAH DI JL SINDANG BARANG ANTAPANI KOT...  Antapani
# 214   Rumah Riv. Arcamanik-Antapani, Baru 2 LANTAI M...  Antapani
# 416   Rumah Baru Murah Mewah Arcamanik-Antapani Kota...  Antapani
# 911            DIJUAL RUMAH MURAH SIAP HUNI DI ANTAPANI  Antapani
# 1028                         Properti Dijual di Bandung  Antapani
# 1029                         Properti Dijual di Bandung  Antapani
#
#       Lahan Parkir  Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah  \
# 13             NaN         15.0          4.0          200.0       168.0
# 77             NaN          3.0          2.0           70.0       167.0
# 78             NaN          3.0          2.0           70.0       167.0
# 80             NaN          3.0          3.0          160.0       232.0
# 90             1.0          3.0          2.0           70.0       168.0
# 129            NaN          5.0          3.0          280.0       140.0
# 214            2.0          3.0          2.0           62.0        63.0
# 416            2.0          3.0          2.0           60.0        85.0
# 911            NaN          5.0          4.0          120.0       168.0
# 1028           NaN          NaN          NaN            NaN         NaN
# 1029           NaN          NaN          NaN            NaN         NaN
#
#                 Harga
# 13    Rp1.250.000.000
# 77    Rp1.100.000.000
# 78    Rp1.100.000.000
# 80    Rp1.650.000.000
# 90    Rp1.100.000.000
# 129   Rp2.650.000.000
# 214     Rp795.000.000
# 416     Rp980.500.000
# 911   Rp1.250.000.000
# 1028  Rp4.000.000.000
# 1029  Rp4.000.000.000

# %%
house = house.drop_duplicates(subset=['Judul', 'Lahan Parkir', 'Kamar Tidur', 'Kamar Mandi', 'Luas Tanah', 'Luas Bangunan', 'Harga'], keep=False)

# %%
house.isna().sum()
# Out:
# Link               0
# Judul              0
# Kecamatan          0
# Lahan Parkir     502
# Kamar Tidur        0
# Kamar Mandi        0
# Luas Bangunan      0
# Luas Tanah         0
# Harga              0
# dtype: int64

# %%
house['Lahan Parkir'] = house['Lahan Parkir'].fillna(0)

# %%
house.isna().sum()
# Out:
# Link             0
# Judul            0
# Kecamatan        0
# Lahan Parkir     0
# Kamar Tidur      0
# Kamar Mandi      0
# Luas Bangunan    0
# Luas Tanah       0
# Harga            0
# dtype: int64

# %%
house.head()
# Out:
#                                                 Link  \
# 0  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 2  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 3  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 4  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                Judul Kecamatan  Lahan Parkir  \
# 0     Rumah Murah Jalan Sunda Asia Afrika Jarang Ada  Antapani           6.0
# 1            Rumah Minimalis Siap Huni di pusat kota  Antapani           2.0
# 2         JUAL MURAH RUMAH LOKASI PREMIUM DI BANDUNG  Antapani           0.0
# 3  Rumah Industri di Turangga Buahbatu dkt Sailen...  Antapani           2.0
# 4    Rumah ready baru industrial diturangga buahbatu  Antapani           2.0
#
#    Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah             Harga
# 0          3.0          4.0          500.0       568.0  Rp11.000.000.000
# 1          5.0          3.0          370.0       259.0  Rp18.000.000.000
# 2          8.0          6.0          693.0      1035.0  Rp27.000.000.000
# 3          4.0          3.0          131.0       108.0   Rp2.500.000.100
# 4          4.0          3.0          131.0       108.0   Rp2.500.000.000

# %%
house['Harga'] = house['Harga'].str.replace('.', '')
house['Harga'] = house['Harga'].str.replace('Rp', '')
house['Harga'] = house['Harga'].astype(int)

# %%
house.head()
# Out:
#                                                 Link  \
# 0  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 2  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 3  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 4  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                Judul Kecamatan  Lahan Parkir  \
# 0     Rumah Murah Jalan Sunda Asia Afrika Jarang Ada  Antapani           6.0
# 1            Rumah Minimalis Siap Huni di pusat kota  Antapani           2.0
# 2         JUAL MURAH RUMAH LOKASI PREMIUM DI BANDUNG  Antapani           0.0
# 3  Rumah Industri di Turangga Buahbatu dkt Sailen...  Antapani           2.0
# 4    Rumah ready baru industrial diturangga buahbatu  Antapani           2.0
#
#    Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah        Harga
# 0          3.0          4.0          500.0       568.0  11000000000
# 1          5.0          3.0          370.0       259.0  18000000000
# 2          8.0          6.0          693.0      1035.0  27000000000
# 3          4.0          3.0          131.0       108.0   2500000100
# 4          4.0          3.0          131.0       108.0   2500000000

# %%
house['Harga (Juta Rupiah)'] = house['Harga'] / 1000000
house['Harga (Juta Rupiah)'] = house['Harga (Juta Rupiah)'].round(2)

# %%
house.head()
# Out:
#                                                 Link  \
# 0  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 2  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 3  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 4  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                Judul Kecamatan  Lahan Parkir  \
# 0     Rumah Murah Jalan Sunda Asia Afrika Jarang Ada  Antapani           6.0
# 1            Rumah Minimalis Siap Huni di pusat kota  Antapani           2.0
# 2         JUAL MURAH RUMAH LOKASI PREMIUM DI BANDUNG  Antapani           0.0
# 3  Rumah Industri di Turangga Buahbatu dkt Sailen...  Antapani           2.0
# 4    Rumah ready baru industrial diturangga buahbatu  Antapani           2.0
#
#    Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah        Harga  \
# 0          3.0          4.0          500.0       568.0  11000000000
# 1          5.0          3.0          370.0       259.0  18000000000
# 2          8.0          6.0          693.0      1035.0  27000000000
# 3          4.0          3.0          131.0       108.0   2500000100
# 4          4.0          3.0          131.0       108.0   2500000000
#
#    Harga (Juta Rupiah)
# 0              11000.0
# 1              18000.0
# 2              27000.0
# 3               2500.0
# 4               2500.0

# %%
house.describe()
# Out:
#        Lahan Parkir  Kamar Tidur  Kamar Mandi  Luas Bangunan   Luas Tanah  \
# count   1060.000000  1060.000000  1060.000000    1060.000000  1060.000000
# mean       1.372642     3.627358     2.476415     148.718868   153.472642
# std        4.928939     1.520960     1.167069     121.992175   139.193828
# min        0.000000     1.000000     1.000000       2.000000    37.000000
# 25%        0.000000     3.000000     2.000000      80.000000    90.000000
# 50%        1.000000     3.000000     2.000000     117.500000   118.000000
# 75%        1.000000     4.000000     3.000000     198.000000   168.000000
# max       90.000000    14.000000     9.000000    1351.000000  2259.000000
#
#               Harga  Harga (Juta Rupiah)
# count  1.060000e+03          1060.000000
# mean   1.891676e+09          1891.676245
# std    2.524858e+09          2524.858023
# min    1.450000e+08           145.000000
# 25%    9.500000e+08           950.000000
# 50%    1.300000e+09          1300.000000
# 75%    1.999250e+09          1999.250000
# max    4.500000e+10         45000.000000

# %%
# Set style for the plots
sns.set(style="whitegrid")

# Create a scatter plot for 'Luas Tanah' vs 'Harga'
plt.figure(figsize=(6, 4))
sns.scatterplot(x=house['Luas Tanah'], y=house['Harga (Juta Rupiah)'])
plt.title('Scatter Plot of Luas Tanah vs Harga')
plt.xlabel('Luas Tanah (m²)')
plt.ylabel('Harga (Juta)')
plt.show()

# Create a scatter plot for 'Luas Bangunan' vs 'Harga'
plt.figure(figsize=(6, 4))
sns.scatterplot(x=house['Luas Bangunan'], y=house['Harga (Juta Rupiah)'])
plt.title('Scatter Plot of Luas Bangunan vs Harga')
plt.xlabel('Luas Bangunan (m²)')
plt.ylabel('Harga (Juta)')
plt.show()

# %%
# Menghapus outlier menggunakan IQR (Interquartile Range)
Q1 = house['Harga'].quantile(0.25)
Q3 = house['Harga'].quantile(0.75)
IQR = Q3 - Q1
house = house[~((house['Harga'] < (Q1 - 1.5 * IQR)) | (house['Harga'] > (Q3 + 1.5 * IQR)))]

# %%
# Set style for the plots
sns.set(style="whitegrid")

# Create a scatter plot for 'Luas Tanah' vs 'Harga'
plt.figure(figsize=(8, 4))
sns.scatterplot(x=house['Luas Tanah'], y=house['Harga (Juta Rupiah)'])
plt.title('Scatter Plot of Luas Tanah vs Harga')
plt.xlabel('Luas Tanah (m²)')
plt.ylabel('Harga (Juta)')
plt.show()

# Create a scatter plot for 'Luas Bangunan' vs 'Harga'
plt.figure(figsize=(8, 4))
sns.scatterplot(x=house['Luas Bangunan'], y=house['Harga (Juta Rupiah)'])
plt.title('Scatter Plot of Luas Bangunan vs Harga')
plt.xlabel('Luas Bangunan (m²)')
plt.ylabel('Harga (Juta)')
plt.show()

# %%
outliers = house.loc[house['Luas Tanah'] >= 400]
outliers
# Out:
#                                                    Link  \
# 27    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 63    https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 583   https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 810   https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 1036  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                   Judul Kecamatan  \
# 27    DIJUAL RUMAH VILLA DI LEMBANG, UDARA SEJUK PEG...  Antapani
# 63                 RUMAH PREMIUM ANTAPANI BANDUNG TIMUR  Antapani
# 583   Rumah Luas400 di Antapani Randusari dkt Pratis...  Antapani
# 810   Dijual Harga TERMURAH Rumah Di Dalam Komplek A...  Antapani
# 1036  Rumah Hook siap huni Antapani Kiaracondong Ban...  Antapani
#
#       Lahan Parkir  Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah  \
# 27             0.0          2.0          2.0          100.0       588.0
# 63             0.0          4.0          4.0          145.0      1362.0
# 583            0.0          6.0          3.0          450.0       400.0
# 810            0.0          6.0          3.0          450.0       400.0
# 1036           2.0          4.0          3.0          250.0       476.0
#
#            Harga  Harga (Juta Rupiah)
# 27    3000000000              3000.00
# 63    2799680400              2799.68
# 583   3000000000              3000.00
# 810   3000000000              3000.00
# 1036  2500000000              2500.00

# %%
data = house[house['Luas Tanah'] <= 400]

# %%
data.describe()
# Out:
#        Lahan Parkir  Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah  \
# count    973.000000   973.000000   973.000000     973.000000  973.000000
# mean       1.368962     3.476876     2.331963     127.924974  128.053443
# std        5.049400     1.387306     1.014187      73.323593   58.460894
# min        0.000000     1.000000     1.000000       2.000000   37.000000
# 25%        0.000000     3.000000     2.000000      80.000000   90.000000
# 50%        1.000000     3.000000     2.000000     110.000000  109.000000
# 75%        1.000000     4.000000     3.000000     170.000000  150.000000
# max       90.000000    14.000000     9.000000    1001.000000  400.000000
#
#               Harga  Harga (Juta Rupiah)
# count  9.730000e+02           973.000000
# mean   1.424531e+09          1424.531490
# std    7.119371e+08           711.937107
# min    1.450000e+08           145.000000
# 25%    9.250000e+08           925.000000
# 50%    1.299000e+09          1299.000000
# 75%    1.750000e+09          1750.000000
# max    3.500000e+09          3500.000000

# %%
data.head()
# Out:
#                                                 Link  \
# 3  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 4  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 5  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 6  https://www.lamudi.co.id/jual/jawa-barat/bandu...
# 7  https://www.lamudi.co.id/jual/jawa-barat/bandu...
#
#                                                Judul Kecamatan  Lahan Parkir  \
# 3  Rumah Industri di Turangga Buahbatu dkt Sailen...  Antapani           2.0
# 4    Rumah ready baru industrial diturangga buahbatu  Antapani           2.0
# 5  2UNIT RUMAH BARU MODERN KONSEP INDUSTRIAL DI L...  Antapani           0.0
# 6           Jual Rumah Muararajeun Katamso Supratman  Antapani           1.0
# 7               Rumah Murah Tamansari ITB Cihampelas  Antapani           2.0
#
#    Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah       Harga  \
# 3          4.0          3.0          131.0       108.0  2500000100
# 4          4.0          3.0          131.0       108.0  2500000000
# 5          3.0          3.0          130.0       108.0  2500000000
# 6          6.0          3.0           85.0       108.0   890000000
# 7          3.0          2.0          106.0        96.0  1599900000
#
#    Harga (Juta Rupiah)
# 3               2500.0
# 4               2500.0
# 5               2500.0
# 6                890.0
# 7               1599.9

# %%
data = data[data.columns[3:]]
data.head()
# Out:
#    Lahan Parkir  Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah  \
# 3           2.0          4.0          3.0          131.0       108.0
# 4           2.0          4.0          3.0          131.0       108.0
# 5           0.0          3.0          3.0          130.0       108.0
# 6           1.0          6.0          3.0           85.0       108.0
# 7           2.0          3.0          2.0          106.0        96.0
#
#         Harga  Harga (Juta Rupiah)
# 3  2500000100               2500.0
# 4  2500000000               2500.0
# 5  2500000000               2500.0
# 6   890000000                890.0
# 7  1599900000               1599.9

# %%
correlation_matrix = data.corr()

# %%
# Buat heatmap
plt.figure(figsize=(6, 4))  # Sesuaikan ukuran figure sesuai kebutuhan
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

# Tampilkan heatmap
plt.title('Correlation Matrix')
plt.show()

# %%
x = data[['Lahan Parkir','Kamar Tidur', 'Kamar Mandi', 'Luas Tanah', 'Luas Bangunan']]
y = data ['Harga']

# %%
from sklearn.feature_selection import f_regression

# %%
f_regression(x,y)
# Out:
# (array([  1.4213631 , 276.75735199, 408.3815393 , 947.43417093,
#         699.04782675]),
#  array([2.33470451e-001, 7.20172161e-055, 4.46301420e-076, 9.66444200e-146,
#         1.80618746e-116]))

# %%
# Since we are more interested in the latter (p-values), we can just take the second array
p_values = f_regression(x,y)[1]
p_values.round(3)
# Out:
# array([0.233, 0.   , 0.   , 0.   , 0.   ])

# %%
# Remove column name 'A'
data = data.drop(['Lahan Parkir', 'Harga (Juta Rupiah)'], axis=1)

# %%
data
# Out:
#       Kamar Tidur  Kamar Mandi  Luas Bangunan  Luas Tanah       Harga
# 3             4.0          3.0          131.0       108.0  2500000100
# 4             4.0          3.0          131.0       108.0  2500000000
# 5             3.0          3.0          130.0       108.0  2500000000
# 6             6.0          3.0           85.0       108.0   890000000
# 7             3.0          2.0          106.0        96.0  1599900000
# ...           ...          ...            ...         ...         ...
# 1075          2.0          1.0           45.0        79.0   675000000
# 1076          3.0          2.0           75.0        84.0   865000000
# 1077          3.0          3.0           88.0       108.0  1350000000
# 1078          2.0          1.0           41.0       100.0   995000000
# 1079          4.0          2.0          120.0        72.0   950000000
#
# [973 rows x 5 columns]
